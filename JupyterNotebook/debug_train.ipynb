# %% [markdown]
# for Colab

# %%
# %cd /content/drive/MyDrive/group-1.3/scripts
# %load_ext autoreload
# %autoreload 2
# Out:
# /content/drive/MyDrive/group-1.3/scripts
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# !pip install transformers
# Out:
# ...
#      |████████████████████████████████| 2.3MB 7.6MB/s
# ...
#      |████████████████████████████████| 901kB 37.0MB/s
# ...
#      |████████████████████████████████| 3.3MB 34.7MB/s
# ...

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# %cd ../scripts

# %%
hparams = {
    'lr': 1e-4,
    'batch_size': 256,
    'student': {
        'pretrained': 'bert-base-uncased',
        'pretrained_dim': 768,
        'num_aspect': 13,
    },
    'description': 'organic food baseline',
    'save_dir': '../ckpt/',
    'aspect_init_file': '../processed/seedwords_5.txt',
    'train_file': '../processed/processed_comments.pkl',
    'test_file': './data/bags_test.json',
    'general_asp': 12,
    'maxlen': 40
}

# %%
from train import *

# %%
trainer = Trainer(hparams, 'cuda')
# Out:
# INFO:root:loading dataset...
# INFO:root:dataset_size: 458085
# INFO:root:loading model...
# asp_category: 13
# bag_dim: 64
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
trainer.train(3)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# INFO:root:Epoch: 0
#
#
#
#
#
# ...
#   0%|          | 1/1790 [00:03<1:39:44,  3.34s/it]
#
#
#
#
# ...
# loss:659.267:   0%|          | 2/1790 [00:05<1:25:04,  2.85s/it]
#
#
#
#
# ...
# loss:644.638:   0%|          | 3/1790 [00:05<1:07:16,  2.26s/it]
#
#
#
#
# ...
# loss:643.258:   0%|          | 4/1790 [00:06<54:57,  1.85s/it]
#
#
#
#
# ...
# loss:643.392:   0%|          | 5/1790 [00:07<46:19,  1.56s/it]
#
#
#
#
# ...
# loss:642.932:   0%|          | 6/1790 [00:08<40:11,  1.35s/it]
#
#
#
#
# ...
# loss:642.197:   0%|          | 7/1790 [00:09<35:57,  1.21s/it]
#
#
#
#
# ...

# %%
from dataset import Dataset

# %%
aspect_init_file = "../processed/seedwords_5.txt"
data_file = "../processed/processed_comments.pkl"

# %%
ds = Dataset(aspect_init_file, data_file)

# %%
import pandas as pd
df = pd.read_pickle(data_file)
print(df)

# %%
# text = df.comment.astype('str').tolist()
text = df.iloc[:, 0].astype('str').tolist()
# print(text)
print(type(text[0]))
print(text[:10])

# %%
text.sort(key=len)

# %%
from nltk.tokenize import sent_tokenize
text_eg = text[30000:30010]
print(text_eg)
sents = []
for i in range(len(text_eg)):
    a = sent_tokenize(text_eg[i])
    print(a)
    sents += a
print(sents)
