# %% [markdown]
# # Clarity Scoring Function

# %%
import sys
import re
from pprint import pprint
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import HashingVectorizer
from numpy import log
from scipy.special import rel_entr
import pandas as pd
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\kevin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
header_columns = 'Author_ID|Author_name|Comment_number|Sentence_number|Domain_Relevance|Sentiment|Entity|Attribute|Sentence|Source_file|Annotator|Aspect'.split('|')
# domain_relevance_classes = ['0', '9']
# entity_classes = ['g', 'p', 'f', 'c', 'cg', 'cp', 'cf', 'cc', 'gg']
attribute_classes = ['g', 'p', 't', 'q', 's', 'h', 'c', 'll', 'or', 'l', 'av', 'e', 'a', 'pp']
# sentiment_classes = ['p', 'n', '0']
# print(len(attribute_classes) * len(entity_classes))

# %%
# %%time
df = pd.read_csv('../dataframe.csv', sep='|', names = header_columns)
print(len(df))
df.sample(5)
# Out:
# 8824
# Wall time: 81 ms
#                Author_ID         Author_name Comment_number Sentence_number  \
# 3066      Andrew-Wolff-2        Andrew Wolff            648               2
# 6734       A-S-Ramprasad       A.S Ramprasad             53              12
# 3573         Ron-DePaepe         Ron DePaepe             36              10
# 7356       Adeela-Masood       Adeela Masood           1306               5
# 5776  Tejomaye-Upmanvaya  Tejomaye Upmanvaya           1265               5
#
#      Domain_Relevance Sentiment Entity Attribute  \
# 3066                9         n      p         g
# 6734                0       NaN    NaN       NaN
# 3573                0       NaN    NaN       NaN
# 7356                9         0      p         g
# 5776                9         n      g         p
#
#                                                Sentence Source_file Annotator  \
# 3066  At least, I do not have a strong preference fo...  quora.json   sarthak
# 6734    In fact they would not come from ripened fruit.  quora.json    hannah
# 3573  :) Gluten affects your body in good ways, as t...  quora.json    hannah
# 7356  And I tell them that at least there is a chanc...  quora.json   florian
# 5776  Buying organic food daily can be heavy on the ...  quora.json   florian
#
#        Aspect
# 3066      p-g
# 6734  nan-nan
# 3573  nan-nan
# 7356      p-g
# 5776      g-p

# %%
# taking only relvant
df_relevant = df.loc[df['Domain_Relevance'] == '9']
print(len(df_relevant))
df_relevant.sample(5)
# Out:
# 4687
#                   Author_ID          Author_name Comment_number  \
# 564   Raja-Sekhar-Bandaru-1  Raja Sekhar Bandaru           1756
# 7844           Matt-Ackeret         Matt Ackeret            745
# 4228           Janice-Boelk         Janice Boelk             85
# 5936       Tejashri-Khade-1       Tejashri Khade            670
# 3143        Addison-Manning      Addison Manning             47
#
#      Sentence_number Domain_Relevance Sentiment Entity Attribute  \
# 564                8                9         n      c         l
# 7844               2                9         n      p         h
# 4228              11                9         n     cp         s
# 5936               2                9         0      f         c
# 3143               4                9         p      f         g
#
#                                                Sentence Source_file Annotator  \
# 564   None of the natural farmers around the city su...  quora.json     felix
# 7844  Also, there is no proof that organic food is a...  quora.json   sarthak
# 4228  Other ingredients would probably be toxic chem...  quora.json    hannah
# 5936  Organic cultivation excludes the use of artifi...  quora.json   sarthak
# 3143  Full disclosure: I am an organic farmer, I kno...  quora.json    hannah
#
#      Aspect
# 564     c-l
# 7844    p-h
# 4228   cp-s
# 5936    f-c
# 3143    f-g

# %%
# lemmatize and stop word
lemmatize = True
remove_stopwords = True

if lemmatize:
    lemmatizer = WordNetLemmatizer()
else:
    lemmatizer = None

if remove_stopwords:
    stop_words = set(stopwords.words('english'))
else:
    stop_words = set()

# %%
token_pattern = re.compile(r'(?u)\b\w\w+\b')

# %%
# taking aspects to be attributes
aspects = attribute_classes
print(aspects)

# a dictionary of aspects and segments associated with that aspect
aspect_segments = dict([(aspect, []) for aspect in aspects])
print(aspect_segments)

# a list for all segments
all_segs = []
# Out:
# ['g', 'p', 't', 'q', 's', 'h', 'c', 'll', 'or', 'l', 'av', 'e', 'a', 'pp']
# {'g': [], 'p': [], 't': [], 'q': [], 's': [], 'h': [], 'c': [], 'll': [], 'or': [], 'l': [], 'av': [], 'e': [], 'a': [], 'pp': []}

# %%
# labelling scheme of annotated dataset round 3
df_asp = pd.read_excel('../Labeling Workshop_updated_18-10-19.xlsx', sheet_name='Labeling Scheme')

# a dictionary with aspect codes and its labels
asp_meaning = {}
for index, row in df_asp.iterrows():
    if(row[0] == 'attribute'):
        asp_meaning[row[1]] = row[2]
pprint(asp_meaning, sort_dicts= False)
# Out:
# {'g': 'general',
#  'p': 'price',
#  't': 'taste',
#  'q': 'nutritional quality/freshness/appearance',
#  's': 'safety',
#  'h': 'healthiness',
#  'c': 'chemicals/pesticides',
#  'll': 'label',
#  'or': 'origin, source',
#  'l': 'local',
#  'av': 'availability',
#  'e': 'environment',
#  'a': 'animal welfare',
#  'pp': 'productivity'}

# %%
# %%time
for i, row in df_relevant.iterrows():  
    if row['Attribute']!='NaN':
        seg_body = row['Sentence']
        seg_aspect = row['Attribute']
        seg_words = [word for word in token_pattern.findall(seg_body.lower())
                              if word not in stop_words]

        if lemmatizer is not None:
            seg_words = [lemmatizer.lemmatize(word) for word in seg_words]
        # prepared segment
        seg_prep = ' '.join(seg_words)
        # add to aspect-segment dictionary
        aspect_segments[seg_aspect].append(seg_prep)
        # add to all segments list
        all_segs.append(seg_prep)
print(len(all_segs))
# Out:
# 4687
# Wall time: 2.37 s

# %%
# compute tfidf scores
vectorizer = TfidfVectorizer(stop_words='english' if remove_stopwords else None,
        norm='l1', use_idf=True)
vectorizer.fit(all_segs)
gl_freq = vectorizer.transform([' '.join(all_segs)]).toarray()[0]
print(len(gl_freq))
# Out:
# 5828

# %%
# global scores
gl_scores = {}
for term, idx in vectorizer.vocabulary_.items():
    gl_scores[term] = gl_freq[idx]
print (len(gl_scores))
# Out:
# 5828

# %%
# %%time
asp_scores = dict([(aspect, {}) for aspect in aspect_segments.keys()])
sorted_asp_scores = dict([(aspect, {}) for aspect in aspect_segments.keys()])
score_seed_words = dict([(aspect, []) for aspect in asp_meaning.values()])

for aspect, segments in aspect_segments.items():
    # aspect-specific scores
    asp_freq = vectorizer.transform([' '.join(segments)]).toarray()[0]
    
    # entropies correspond to clarity scores
    entropies = rel_entr(asp_freq, gl_freq) / log(2)
    for term, idx in vectorizer.vocabulary_.items():
        asp_scores[aspect][term] = entropies[idx]
        
    # sort by score and write to sorted_asp_scores if > 0
    scores = sorted(asp_scores[aspect].items(), reverse=True, key=lambda x:x[1])
    for term, cla in scores[0:10]:
        if cla > 0:
            sorted_asp_scores[aspect][term] = cla
            score_seed_words[asp_meaning[aspect]].append(term)

pprint(sorted_asp_scores, sort_dicts=False)
pprint(score_seed_words, sort_dicts=False)

df_out = pd.DataFrame.from_dict(data=score_seed_words, orient='index')
if remove_stopwords:
    df_out.to_excel('../score_seed_words_remove_stop.xlsx')
else:
    df_out.to_excel('../score_seed_words.xlsx')
# Out:
# {'g': {'gmo': 0.003483305824339285,
#        'farming': 0.003318456952304896,
#        'store': 0.0027445582194592874,
#        'organic': 0.002513442297520986,
#        'india': 0.0022430018742386993,
#        'definition': 0.002232780185675268,
#        'online': 0.0019182282518315594,
#        'farm': 0.001891181489807445,
#        'seed': 0.0018605691653413587,
#        'start': 0.0016999618119770872},
#  'p': {'price': 0.07027722837749699,
#        'expensive': 0.06539105340635938,
#        'cost': 0.057431297271537375,
#        'pay': 0.023146861379406955,
#        'money': 0.02123499553408327,
#        'demand': 0.020216749973225374,
#        'higher': 0.018490050547252494,
#        'extra': 0.018220274952386796,
#        'charge': 0.014430447027442842,
#        'afford': 0.014028622130207051},
#  't': {'taste': 0.2687317959602853,
#        'better': 0.07084940625304122,
#        'flavor': 0.050404405110374,
#        'difference': 0.03837601208118237,
#        'tasty': 0.02259570188815016,
#        'fruit': 0.02038661851720556,
#        'delicious': 0.020216858696706676,
#        'sweeter': 0.01745427612667468,
#        'flavour': 0.01745427612667468,
#        'beef': 0.01729477690616275},
#  'q': {'nutrient': 0.03984007102337286,
#        'nutritional': 0.03366892282697721,
#        'quality': 0.028631940119583105,
#        'nutritious': 0.02840557186414048,
#        'vitamin': 0.02533406807199727,
#        'antioxidant': 0.02175750552140329,
#        'higher': 0.01752410032028844,
#        'nutrition': 0.015176814463535861,
#        'milk': 0.012942253546180163,
#        'tomato': 0.012078445598442808},
#  's': {'safer': 0.035532223318235766,
#        'safe': 0.03479031735629574,
#        'safety': 0.02478274374556284,
#        'dangerous': 0.01670242486894059,
#        'human': 0.015375165888956018,
#        'cancer': 0.014850471094786846,
#        'consensus': 0.01021926866780493,
#        'test': 0.010057351560035793,
#        'harmful': 0.008767140300783528,
#        'cause': 0.008731309762709086},
#  'h': {'health': 0.046350262185763554,
#        'healthier': 0.02968553428943411,
#        'healthy': 0.029524831122538616,
#        'benefit': 0.019556589032699856,
#        'food': 0.01525358791053819,
#        'body': 0.011776757058095694,
#        'study': 0.010570592878605336,
#        'disease': 0.008825265072080838,
#        'powder': 0.0084974063331937,
#        'evidence': 0.008338286652932595},
#  'c': {'pesticide': 0.074318618334827,
#        'chemical': 0.042909021061311906,
#        'fertilizer': 0.02214274055484185,
#        'synthetic': 0.017007714922409135,
#        'use': 0.015439930040707326,
#        'residue': 0.013457868395941023,
#        'used': 0.013244248872486923,
#        'herbicide': 0.009411646094087638,
#        'toxic': 0.00916315204358954,
#        'approved': 0.0073314287609984536},
#  'll': {'label': 0.060818082350683596,
#         'certified': 0.042315468132931425,
#         'certification': 0.04138552401624765,
#         'usda': 0.03127626736451933,
#         'marketing': 0.016536149143251574,
#         'labeled': 0.014242901803482621,
#         'organic': 0.012961097205801396,
#         'ingredient': 0.012945140135940739,
#         'certifying': 0.011288993023705802,
#         'labeling': 0.010819197630768846},
#  'or': {'china': 0.0370962426037172,
#         'brand': 0.03387123698429176,
#         'strictly': 0.025610465841827794,
#         'versus': 0.025368448551035427,
#         'country': 0.024376719159406264,
#         'orchardists': 0.024265252017459812,
#         'cultivable': 0.024265252017459812,
#         'origin': 0.02296175311954684,
#         'sold': 0.022880875321789153,
#         'mile': 0.022176249579562466},
#  'l': {'local': 0.2042971899835304,
#        'locally': 0.10752940277989313,
#        'burger': 0.05422597658149195,
#        'fresh': 0.038942287526348054,
#        'buy': 0.0367528355369991,
#        'push': 0.03625961855964346,
#        'allotment': 0.036150651054327965,
#        'degrades': 0.03447730935391101,
#        'season': 0.03336885519738468,
#        'travel': 0.030266132054655198},
#  'av': {'online': 0.05159981523547074,
#         'sale': 0.032832708413960555,
#         'shop': 0.027615128387952936,
#         'bangalore': 0.02626160315957077,
#         'supplier': 0.024681386905486293,
#         'location': 0.022015886338408078,
#         'delhi': 0.02178601909961788,
#         'market': 0.020235517382975184,
#         'store': 0.020235517382975184,
#         'agro': 0.019119417941675074},
#  'e': {'environment': 0.06466583303524993,
#        'soil': 0.047492889110324885,
#        'farming': 0.026488772259456526,
#        'environmental': 0.019203734860303325,
#        'environmentally': 0.016699155124354215,
#        'sustainable': 0.016413935480480778,
#        'destructive': 0.01625323665975454,
#        'equally': 0.015929128588480584,
#        'water': 0.01454609413917475,
#        'better': 0.012192261409969603},
#  'a': {'animal': 0.08044989603977876,
#        'cow': 0.06490126857101741,
#        'chicken': 0.051871339837664655,
#        'hen': 0.04013565784559975,
#        'feed': 0.03252502842565442,
#        'cage': 0.02992179465881363,
#        'fed': 0.029911590594918363,
#        'access': 0.027649444279827746,
#        'outdoors': 0.026649925011777854,
#        'antibiotic': 0.025018939397597834},
#  'pp': {'yield': 0.07606532924597746,
#         'crop': 0.03159870077697038,
#         'land': 0.028644442812932727,
#         'acre': 0.024617693662135037,
#         'population': 0.017816487270407803,
#         'le': 0.015236325507372604,
#         'farming': 0.013777354214198047,
#         'impact': 0.013398260858445614,
#         'grow': 0.013278032250785419,
#         'economic': 0.012969065757902678}}
# {'general': ['gmo',
#              'farming',
#              'store',
#              'organic',
#              'india',
#              'definition',
#              'online',
#              'farm',
#              'seed',
#              'start'],
#  'price': ['price',
#            'expensive',
#            'cost',
#            'pay',
#            'money',
#            'demand',
#            'higher',
#            'extra',
#            'charge',
#            'afford'],
#  'taste': ['taste',
#            'better',
#            'flavor',
#            'difference',
#            'tasty',
#            'fruit',
#            'delicious',
#            'sweeter',
#            'flavour',
#            'beef'],
#  'nutritional quality/freshness/appearance': ['nutrient',
#                                               'nutritional',
#                                               'quality',
#                                               'nutritious',
#                                               'vitamin',
#                                               'antioxidant',
#                                               'higher',
#                                               'nutrition',
#                                               'milk',
#                                               'tomato'],
#  'safety': ['safer',
#             'safe',
#             'safety',
#             'dangerous',
#             'human',
#             'cancer',
#             'consensus',
#             'test',
#             'harmful',
#             'cause'],
#  'healthiness': ['health',
#                  'healthier',
#                  'healthy',
#                  'benefit',
#                  'food',
#                  'body',
#                  'study',
#                  'disease',
#                  'powder',
#                  'evidence'],
#  'chemicals/pesticides': ['pesticide',
#                           'chemical',
#                           'fertilizer',
#                           'synthetic',
#                           'use',
#                           'residue',
#                           'used',
#                           'herbicide',
#                           'toxic',
#                           'approved'],
#  'label': ['label',
#            'certified',
#            'certification',
#            'usda',
#            'marketing',
#            'labeled',
#            'organic',
#            'ingredient',
#            'certifying',
#            'labeling'],
#  'origin, source': ['china',
#                     'brand',
#                     'strictly',
#                     'versus',
#                     'country',
#                     'orchardists',
#                     'cultivable',
#                     'origin',
#                     'sold',
#                     'mile'],
#  'local': ['local',
#            'locally',
#            'burger',
#            'fresh',
#            'buy',
#            'push',
#            'allotment',
#            'degrades',
#            'season',
#            'travel'],
#  'availability': ['online',
#                   'sale',
#                   'shop',
#                   'bangalore',
#                   'supplier',
#                   'location',
#                   'delhi',
#                   'market',
#                   'store',
#                   'agro'],
#  'environment': ['environment',
#                  'soil',
#                  'farming',
#                  'environmental',
#                  'environmentally',
#                  'sustainable',
#                  'destructive',
#                  'equally',
#                  'water',
#                  'better'],
#  'animal welfare': ['animal',
#                     'cow',
#                     'chicken',
#                     'hen',
#                     'feed',
#                     'cage',
#                     'fed',
#                     'access',
#                     'outdoors',
#                     'antibiotic'],
#  'productivity': ['yield',
#                   'crop',
#                   'land',
#                   'acre',
#                   'population',
#                   'le',
#                   'farming',
#                   'impact',
#                   'grow',
#                   'economic']}
# Wall time: 949 ms
